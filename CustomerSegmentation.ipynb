# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read dataset
df= pd.read_csv('../Data/processed_data.csv')
# Convert date string to python date
Date= []
DateStr= [str(i[0:10]) for i in df.Date]
for d in DateStr:
    Date.append( datetime.datetime.strptime(d, "%Y-%m-%d").date() )
df= df.drop('Date',1)
df= df.drop('Unnamed: 0',1)
df['Date']= Date
df['WeekDay']= map(lambda x: x.weekday(), df.Date)
df.head()
# Out:
#    CustID AgeCode AreaCode         ProdID  Amount  Asset  Price  maxPrice  \
# 0   46855      D        E   4710085120468       3     51     57        21
# 1  539166      E        E   4714981010038       2     56     48        28
# 2  663373      F        E   4710265847666       1    180    135       195
# 3  340625      A        E   4710085120697       1     17     24        24
# 4  236645      D        H   8999002568972       2    128    170        85
#
#    unitPrice  Recency  ReceiptNo  ProdClass  DistanceCode        Date  WeekDay
# 0         19      100       1651     110411             0  2000-11-01        2
# 1         24      100      16973     130315             0  2000-11-01        2
# 2        135      100      20700     110217             0  2000-11-01        2
# 3         24      100      11843     110411             0  2000-11-01        2
# 4         85      100       9125     712901             7  2000-11-01        2

# %%
# Customer segmentation based on following features:
# mean_basket_recency, std_basket_recency, std_basket_value  <-- risk
# mean_basket_value, total_value, total_discounts  <-- profitability

# %% [markdown]
# Time to build aggregated customer dataset

# %%
# start with aggregation per receipt
df2= df.groupby(['ReceiptNo'])
basket_recency= df2.Recency.agg(np.mean).reset_index()
basket_value= df2.Price.agg(np.sum).reset_index()
basket_discount= df2.apply(lambda x: np.sum( ( x.maxPrice - x.unitPrice ) * x.Amount ) ).reset_index()

# %%
rec_df= df2.nth(0).reset_index(drop=True)
rec_df= rec_df.loc[:,['CustID','AgeCode','AreaCode','Recency','ReceiptNo','DistanceCode','Date','WeekDay']]
# Out:
#    CustID AgeCode AreaCode  Recency  ReceiptNo  DistanceCode        Date  \
# 0    1069      K        E       100          0             0  2000-11-13
# 1    1069      K        E        69          1             0  2001-01-21
# 2    1069      K        E        13          2             0  2001-02-03
# 3    1069      K        E         7          3             0  2001-02-10
# 4    1113      K        F       100          4             1  2000-11-12
#
#    WeekDay
# 0        0
# 1        6
# 2        5
# 3        5
# 4        6

# %%
buff= rec_df.copy()
rec_df= pd.merge( buff, basket_value, on="ReceiptNo", how='left' )
buff= rec_df.copy()
rec_df= pd.merge( buff, basket_discount, on="ReceiptNo", how='left' )
rec_df.columns= ['CustID','AgeCode','AreaCode','Recency','ReceiptNo',
                 'DistanceCode','Date','WeekDay','BasketValue','BasketDiscount']
rec_df.head()
# Out:
#    CustID AgeCode AreaCode  Recency  ReceiptNo  DistanceCode        Date  \
# 0    1069      K        E       100          0             0  2000-11-13
# 1    1069      K        E        69          1             0  2001-01-21
# 2    1069      K        E        13          2             0  2001-02-03
# 3    1069      K        E         7          3             0  2001-02-10
# 4    1113      K        F       100          4             1  2000-11-12
#
#    WeekDay  BasketValue  BasketDiscount
# 0        0          187               0
# 1        6          971              99
# 2        5          496             222
# 3        5          290              60
# 4        6          420              47

# %%
# Now aggregate per customer
df3= rec_df.groupby(['CustID'])
#
# Risk
mean_basket_recency= df3.Recency.agg(np.mean)
std_basket_recency= df3.Recency.agg(np.std)
std_basket_value= df3.BasketValue.agg(np.std)
#
# Profitability
mean_basket_value= df3.BasketValue.agg(np.mean)
total_value= df3.BasketValue.agg(np.sum)
total_discounts= df3.BasketDiscount.agg(np.sum)

# %%
cust_df= df3.nth(0).reset_index()
cust_df= cust_df.ix[:,['CustID','AgeCode','AreaCode','DistanceCode']]
cust_df.head()
# Out:
#    CustID AgeCode AreaCode  DistanceCode
# 0    1069      K        E              0
# 1    1113      K        F              1
# 2    1250      D        D              2
# 3    1359      K        G              6
# 4    1823      K        D              2

# %%
buff= cust_df.copy()
cust_df= pd.merge( buff, mean_basket_recency.reset_index(), on="CustID", how='left' )
cust_df.columns.values[4]= 'MeanRecency'
#
buff= cust_df.copy()
cust_df= pd.merge( buff, std_basket_recency.reset_index(), on="CustID", how='left' )
cust_df.columns.values[5]= 'StdRecency'
#
buff= cust_df.copy()
cust_df= pd.merge( buff, std_basket_value.reset_index(), on="CustID", how='left' )
cust_df.columns.values[6]= 'StdBasketValue'
#
buff= cust_df.copy()
cust_df= pd.merge( buff, mean_basket_value.reset_index(), on="CustID", how='left' )
cust_df.columns.values[7]= 'MeanBasketValue'
#
buff= cust_df.copy()
cust_df= pd.merge( buff, total_value.reset_index(), on="CustID", how='left' )
cust_df.columns.values[8]= 'TotalValue'
#
buff= cust_df.copy()
cust_df= pd.merge( buff, total_discounts.reset_index(), on="CustID", how='left' )
cust_df.columns.values[9]= 'TotalDiscounts'

# %%
NVisits= cust_df.TotalValue / cust_df.MeanBasketValue
cust_df.loc[:,'NVisits']= NVisits

# %%
cust_df.head()
# Out:
#    CustID AgeCode AreaCode  DistanceCode  MeanRecency  StdRecency  \
# 0    1069      K        E              0        47.25   44.902673
# 1    1113      K        F              1        38.75   43.934611
# 2    1250      D        D              2        53.00   66.468037
# 3    1359      K        G              6       100.00         NaN
# 4    1823      K        D              2        61.00   50.467812
#
#    StdBasketValue  MeanBasketValue  TotalValue  TotalDiscounts  NVisits
# 0      347.918573            486.0        1944             381        4
# 1       97.123633            557.5        2230             304        4
# 2       81.317280            791.5        1583              32        2
# 3             NaN            364.0         364               3        1
# 4      413.682245            869.0        2607             202        3

# %%
cust_df.MeanRecency.value_counts()
# Out:
# 100.000000    12045
# 50.500000       221
# 51.000000       205
# 52.000000       188
# 57.000000       187
# 53.000000       183
# 60.000000       161
# 64.000000       161
# 59.000000       150
# 53.500000       147
# 61.000000       145
# 67.000000       133
# 60.500000       133
# 54.000000       132
# 51.500000       132
# 56.000000       130
# 52.500000       122
# 58.000000       121
# 55.000000       111
# 63.000000       107
# 66.000000       107
# 56.500000       105
# 41.000000       104
# 68.000000       101
# 62.000000       101
# 67.500000       100
# 46.000000        98
# 65.000000        96
# 57.500000        92
# 38.000000        92
#               ...
# 13.266667         1
# 17.900000         1
# 11.764706         1
# 6.114286          1
# 12.166667         1
# 5.069767          1
# 7.826087          1
# 7.333333          1
# 3.789474          1
# 7.678571          1
# 22.857143         1
# 7.821429          1
# 12.461538         1
# 8.315789          1
# 11.916667         1
# 7.692308          1
# 10.733333         1
# 15.200000         1
# 10.769231         1
# 14.900000         1
# 12.076923         1
# 15.916667         1
# 7.172414          1
# 13.400000         1
# 3.444444          1
# 5.675676          1
# 13.133333         1
# 4.617021          1
# 8.080000          1
# 6.838710          1
# dtype: int64
