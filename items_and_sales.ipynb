# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster
import sklearn.decomposition
import sklearn.preprocessing
import statsmodels
# %matplotlib inline

# %%
# Read dataset
df= pd.read_csv('../Data/processed_data.csv')
# Convert date string to python date
Date= []
DateStr= [str(i[0:10]) for i in df.Date]
for d in DateStr:
    Date.append( datetime.datetime.strptime(d, "%Y-%m-%d").date() )
df= df.drop('Date',1)
df= df.drop('Unnamed: 0',1)
df['Date']= Date
df['WeekDay']= map(lambda x: x.weekday(), df.Date)
df.head()
# Out:
#    CustID AgeCode AreaCode         ProdID  Amount  Asset  Price  maxPrice  \
# 0   46855      D        E   4710085120468       3     51     57        21
# 1  539166      E        E   4714981010038       2     56     48        28
# 2  663373      F        E   4710265847666       1    180    135       195
# 3  340625      A        E   4710085120697       1     17     24        24
# 4  236645      D        H   8999002568972       2    128    170        85
#
#    unitPrice  Recency  ReceiptNo  ProdClass  DistanceCode        Date  WeekDay
# 0         19      100       1651     110411             0  2000-11-01        2
# 1         24      100      16973     130315             0  2000-11-01        2
# 2        135      100      20700     110217             0  2000-11-01        2
# 3         24      100      11843     110411             0  2000-11-01        2
# 4         85      100       9125     712901             7  2000-11-01        2

# %%
# What items/classes etc are actually important?

# %%
# aggregate by product:
dfgb= df.groupby('ProdID')
agg_price= dfgb.Price.agg(np.sum).reset_index()
agg_baskets= dfgb.apply(lambda x: len( x.ReceiptNo.unique() )).reset_index()
agg_customers= dfgb.apply(lambda x: len( x.CustID.unique() )).reset_index()
agg_items= dfgb.Amount.agg(np.sum).reset_index()
#
def count_sales(x):
    df= x.reset_index()
    sale= np.where(df.unitPrice <= 0.9 * df.maxPrice)[0]
    rtval= 0.
    if len(sale) > 0:
        rtval= np.sum(df.loc[sale,'Amount'])
    return rtval
#
agg_sale= dfgb.apply(count_sales).reset_index().fillna(0)
agg_sale.columns.values[1]= 'nDis'

# %%
df2= pd.merge(  agg_price, df.loc[:,['ProdID','ProdClass','maxPrice']].drop_duplicates(),
              on='ProdID', how='left')
#
df2= pd.merge(  agg_baskets, df2,
              on='ProdID', how='left')
#
df2= pd.merge(  agg_customers, df2,
              on='ProdID', how='left')
#
df2= pd.merge(  agg_items, df2,
              on='ProdID', how='left')
#
df2= pd.merge(  agg_sale, df2,
              on='ProdID', how='left')
#
df2.columns.values[5]= 'Revenue'
df2.columns.values[4]= 'nBaskets'
df2.columns.values[3]= 'nCustomers'
df2.columns.values[2]= 'nSold'
#df2.columns.values[1]= 'nDiscounted'

# %%
df2.columns
# Out:
# Index([u'ProdID', u'nDis', u'nSold', u'nCustomers', u'nBaskets', u'Revenue', u'ProdClass', u'maxPrice'], dtype='object')

# %%
df2.head()
# Out:
#      ProdID  nDis  nSold  nCustomers  nBaskets  Revenue  ProdClass  maxPrice
# 0  20008819     2     14          13        13     1449     501102       105
# 1  20008932     0     21          20        20     2312     501102       112
# 2  20009168     0     13          12        13     2665     501102       208
# 3  20009199     2     17          16        16     3975     501102       243
# 4  20009229     0      6           6         6      852     501102       142

# %%
df2.to_csv('../Data/prod.csv')

# %%
df2= pd.read_csv('../Data/prod.csv').drop('Unnamed: 0',1)

# %%
df2= df2.sort(columns='Revenue',ascending=False)

# %%
plt.plot(df2.Revenue.cumsum() / df2.Revenue.sum())

# %%
highval= df2[df2.Revenue.cumsum() / df2.Revenue.sum() <= 0.2]

# %%
highval.Revenue.count()
# Out:
# 106

# %%
highval.sort(columns='Revenue',ascending=False)
# Out:
#               ProdID   nDis  nSold  nCustomers  nBaskets  Revenue  ProdClass  \
# 22837  8712045008539   2213   2349         428       566  1540503     560402
# 9679   4710628131012    345   1647         194       330   675112     560402
# 6792   4710114128038   1402   3322        1734      2181   514601     500201
# 11671  4711588210441      0    885          37        37   491292     100516
# 1831        20553418      0    131         129       130   470501     715001
# 9674   4710628119010    133   1053         129       185   433380     560402
# 21218  4909978112950     65    253         151       173   432596     470103
# 22827  8712045000151     34   1018         127       178   428530     560402
# 22624  7610053910787    923   1133         267       356   392581     560201
# 19408  4719090900065   2635   2816        2087      2444   385626     110217
# 20858  4902430493437   1332   1350         257       282   379956     560201
# 7909   4710265849066   2442   2665        1775      2018   378996     110217
# 5359   4710036003581   2709   2732        1421      1622   374068     500201
# 22625  7610053910794    691    986         259       314   344791     560201
# 7977   4710291112172   1619   2783        1411      1641   341911     500201
# 22840  8712045011317     14    850          81       130   340624     560402
# 5370   4710036008562   1351   1422         451       573   282587     560201
# 20810  4902430040334    217    331         186       244   278723     560201
# 19407  4719090900058   1812   1951        1189      1408   278581     110217
# 6791   4710114105046   1456   1998        1129      1384   266696     500210
# 13194  4712425010712   2238   2291        1435      1620   266480     500201
# 2770     22972004664    163    168         160       163   260316     760593
# 10662  4710908131589   2510   2576        1486      1680   259397     500210
# 16786  4714981010038  13719  14537        6026      8476   246747     130315
# 5561   4710043552102    789   1116         738       858   242994     110109
# 10661  4710908131534   1373   1685         985      1143   234882     500201
# 3540    300086780026     48    568          70        91   234086     560402
# 12885  4712162000038   1428   1581         949      1083   233229     110217
# 5735   4710054380619   1625   1908         910      1084   221491     560204
# 5740   4710054510238    575    632         275       337   215509     560201
# ...              ...    ...    ...         ...       ...      ...        ...
# 6599   4710104112924    694    824         548       575   114315     500201
# 16390  4714692002216    129    131         119       125   113250     710301
# 20809  4902430040327    107    134          92       104   112171     560201
# 7224   4710168705056    734   1196         842       868   110923     530105
# 5363   4710036005608    377    434         187       223   110623     560201
# 8111   4710311703014   1281   1385         786       887   110507     110108
# 6283   4710088620156   1007   1407         786       919   109391     110108
# 21603  4973167032060     22     88          67        80   107193     470101
# 5144   4710022101208    482    523         386       406   106312     100311
# 262         20332433     82   1067         754       951   104072     130206
# 9659   4710626622857    681    905         688       774   103718     110507
# 10498  4710777315776     11    106          68        71   103369     100601
# 10657  4710908111116    941   1037         674       735   103336     500202
# 11315  4711271000014   9294  10615        5236      6120   102397     110106
# 10949  4711080010112    159   2597        1513      2251   102290     130206
# 20859  4902430493451     12    135          94       109   101722     560201
# 10771  4710960911082    766    890         525       646   101660     100413
# 19641  4719856840024   1116   1119         298       319   101063     731302
# 4581   4014400901573     39    902         604       703   100557     100106
# 6036   4710085104130    176   1126         389       540   100410     100504
# 5119   4710018008634    333   1467         825      1015    99685     100505
# 5873   4710063312168     49    830         558       796    99584     130204
# 21242  4909978199050      9     36          31        34    98892     470105
# 6516   4710094097768   1241   2410        1050      1448    98701     100507
# 11289  4711258007371     37    640         583       613    97367     110119
# 245         20307585     43    764         558       712    96297     130206
# 23482  9415007601432    128    243         196       225    96263     100401
# 21547  4971883201098    188    260         136       153    95680     560102
# 6630   4710105015118    792   1038         637       972    94541     130204
# 6631   4710105015125    769   1003         673       947    91279     130204
#
#        maxPrice
# 22837       739
# 9679        439
# 6792        169
# 11671       575
# 1831       3790
# 9674        439
# 21218      1800
# 22827       435
# 22624       395
# 19408       185
# 20858       359
# 7909        195
# 5359        185
# 22625       395
# 7977        137
# 22840       419
# 5370        299
# 20810       939
# 19407       195
# 6791        156
# 13194       159
# 2770       1999
# 10662       129
# 16786        28
# 5561        260
# 10661       155
# 3540        435
# 12885       175
# 5735        159
# 5740        438
# ...         ...
# 6599        159
# 16390      1450
# 20809       939
# 7224        109
# 5363        336
# 8111        112
# 6283         89
# 21603      1305
# 5144        255
# 262          99
# 9659        129
# 10498      1050
# 10657       125
# 11315        16
# 10949        40
# 20859       799
# 10771       139
# 19641       158
# 4581        119
# 6036         95
# 5119         72
# 5873        123
# 21242      2925
# 6516         45
# 11289       155
# 245         128
# 23482       425
# 21547       445
# 6630        106
# 6631        106
#
# [106 rows x 8 columns]

# %%
plt.plot( highval.nBaskets / float(len(df.ReceiptNo.unique()) ) *100.)

# %%
commonly_basketed= df2.nBaskets.sort(ascending=False,inplace=False) /float(len(df.ReceiptNo.unique()) ) *100.

# %%
print commonly_basketed
# Out:
# 16786    7.088260
# 11315    5.117998
# 19408    2.043854
# 10949    1.882453
# 6792     1.823914
# 7909     1.687601
# 15159    1.652478
# 6105     1.563833
# 9552     1.538745
# 10662    1.404941
# 7977     1.372326
# 4831     1.368981
# 6114     1.364800
# 5359     1.356437
# 13194    1.354764
# 8767     1.307933
# 6516     1.210925
# 19407    1.177474
# 5116     1.163257
# 6791     1.157404
# 6049     1.134824
# 6809     1.082139
# 10855    1.038653
# 1965     1.005202
# 2913     1.000184
# 6598     0.975096
# 15858    0.959207
# 10661    0.955861
# 23132    0.935791
# 5250     0.930773
#            ...
# 12458    0.000836
# 1017     0.000836
# 15907    0.000836
# 19151    0.000836
# 20117    0.000836
# 17147    0.000836
# 22307    0.000836
# 18904    0.000836
# 16241    0.000836
# 17180    0.000836
# 136      0.000836
# 1764     0.000836
# 23186    0.000836
# 22879    0.000836
# 21787    0.000836
# 3012     0.000836
# 2420     0.000836
# 3070     0.000836
# 3069     0.000836
# 18334    0.000836
# 15668    0.000836
# 23805    0.000836
# 3071     0.000836
# 3039     0.000836
# 1997     0.000836
# 4573     0.000836
# 1521     0.000836
# 7608     0.000836
# 18892    0.000836
# 13494    0.000836
# Name: nBaskets, dtype: float64

# %% [markdown]
# The above gives high revenue and highly sold items.  What is interesting is that most items have nbaskets ~= ncustomers:

# %%
plt.plot(df2.nCustomers, df2.nBaskets/df2.nCustomers, 'b.')

# %% [markdown]
# Maybe focus on product class?
